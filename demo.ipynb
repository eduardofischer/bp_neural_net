# %%
# Funções auxiliares
def print_list_of_lists(list):
    for e in list:
        print(['{:.3f}'.format(n) for n in e])

# %%
import numpy as np
import neural_net as nn

inputs = np.random.uniform(low=0.0, high=1.0, size=5)

net = nn.NeuralNetwork([1, 2, 1])
net.plot()
net.train([[.9, .6, .7]], [[1, 0, 0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-627e08873fd0> in <module>
#       6 net = nn.NeuralNetwork([1, 2, 1])
#       7 net.plot()
# ----> 8 net.train([[.9, .6, .7]], [[1, 0, 0]])
#
# /mnt/c/Users/efisc/OneDrive - inf.ufrgs.br/UFRGS/7° Semestre/Machine Learning/trabalhos/t2/bp_neural_net/neural_net.py in train(self, inputs_array, outputs_array)
#      75   def train(self, inputs_array, outputs_array):
#      76     for inputs, outputs in zip(inputs_array, outputs_array):
# ---> 77       self._update_outputs(inputs)
#      78       self._update_deltas(outputs)
#      79       self._update_weights()
#
# /mnt/c/Users/efisc/OneDrive - inf.ufrgs.br/UFRGS/7° Semestre/Machine Learning/trabalhos/t2/bp_neural_net/neural_net.py in _update_outputs(self, inputs)
#      37       if layer == 0:
#      38         input_weights = [item[0] for item in self.weights[layer]]
# ---> 39         self.outputs[layer] = input_weights * np.array(inputs)
#      40       else:
#      41         neuron_inputs = np.insert(self.outputs[layer - 1], 0, 1)
#
# ValueError: operands could not be broadcast together with shapes (2,) (3,)

# %%
print('Network: \n{}\n'.format(net.network))
# Out:
# Network:
# [1, 2, 1]

# %%
print('Weights:')
print(net.weights)
# Out:
# Weights:
# [[array([0.84687435, 0.77653058]), array([-0.94509727, -0.58336618])], [array([-0.74628692,  0.02460943, -0.16753279])]]

# %%
print('Deltas:')
print_list_of_lists(net.deltas)
# Out:
# Deltas:
# []
# []
# []

# %%
print('Outputs:')
print_list_of_lists(net.outputs)
# Out:
# Outputs:
# []
# []
# []
