# %%
import numpy as np
import neural_net as nn

inputs = np.random.uniform(low=0.0, high=1.0, size=5)

net = nn.NeuralNetwork([3, 4, 2, 3])
net.plot()
net.train([[.5, .6, .7]], [[1, 0, 0]])

print('Network: \n{}\n'.format(net.network))
print('Deltas: \n{}\n'.format(net.deltas))
print('Outputs: \n{}\n'.format(net.outputs))
# Out:
# ...
# 3
# 2
# [0.22418307445520758, 0.66183496805919, 0.6519214840658374]
# [array([-0.25078469, -0.19346926, -0.23995389])]
# [0.42608442079413456, 0.686105770858608, 0.28731954202573406]
# [array([-0.25078469, -0.19346926, -0.23995389])]
# 1
# [0.6250980615332269, 0.5488142865624701]
# [-0.026099647094499686, -0.04471010902840233]
# [0.6683581770771064, 0.8632550553163931]
# [-0.026099647094499686, -0.04471010902840233]
# [0.6820469665600102, 0.4090935170665867]
# [-0.026099647094499686, -0.04471010902840233]
# [0.5864867442708381, 0.5342198589651851]
# [-0.026099647094499686, -0.04471010902840233]
# 0
# [0.7142292040461324, 0.4753323839823441, 0.12591124307668855, 0.1817060692682777]
# [-0.009489442166228105, -0.013759557212247886, -0.00679864872089606, -0.00910950931447333]
# [0.9857503864653994, 0.16384936395809613, 0.8855802214630669, 0.7534420681153329]
# [-0.009489442166228105, -0.013759557212247886, -0.00679864872089606, -0.00910950931447333]
# ...

# %%
np.insert([5, 6 ,7 ,8], 0, 1)
# Out:
# array([1, 5, 6, 7, 8])
