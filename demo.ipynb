# %%
# Funções auxiliares
def print_list_of_lists(list):
    for e in list:
        print(['{:.5f}'.format(n) for n in e])

# %%
import numpy as np
import neural_net as nn

inputs = np.random.uniform(low=0.0, high=1.0, size=5)

net = nn.NeuralNetwork([1, 2, 1],
    [[[0.4, 0.1], [0.3, 0.2]], [[0.7, 0.5, 0.6]]],
    alpha=0.05, lamb=0.0)
    
net.plot()

# %%
net.evaluate([0.42])
# Out:
# array([0.79596607])

# %%
net.cost([0.42], [0.23])
# Out:
# 1.2763768066887786

# %%
net.train([0.13, 0.42], [0.9, 0.23])

# %%
print('Network: \n{}\n'.format(net.network))
# Out:
# Network:
# [1, 2, 1]

# %%
print('Weights:')
print(net.weights)
# Out:
# Weights:
# [array([[0.39863244, 0.09933357],
#        [0.29834101, 0.19919099]]), array([[0.68850016, 0.49298129, 0.59312224]])]

# %%
print('Deltas:')
print(net.deltas)
# Out:
# Deltas:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-da2e913cf7eb> in <module>
#       1 print('Deltas:')
# ----> 2 print_list_of_lists(net.deltas)
#
# NameError: name 'print_list_of_lists' is not defined

# %%
print('Gradients:')
print(net.gradients)
# Out:
# Gradients:
# [array([[0.02735127, 0.01332866],
#        [0.03317988, 0.01618028]]), array([[0.22999675, 0.1403743 , 0.13755523]])]

# %%
print('Outputs:')
print(net.outputs)
# Out:
# Outputs:
# [array(0.42), array([0.60873549, 0.59483749]), array([0.79596607])]
